# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./input/DOSE_V2.csv', encoding='latin-1')

# %%
data.columns
# Out:
# Index(['ï»¿country', 'region', 'GID_0', 'GID_1', 'year', 'grp_lcu', 'pop',
#        'grp_pc_lcu', 'ag_grp_pc_lcu', 'man_grp_pc_lcu', 'serv_grp_pc_lcu',
#        'grp_pc_usd', 'ag_grp_pc_usd', 'man_grp_pc_usd', 'serv_grp_pc_usd',
#        'grp_pc_lcu_2015', 'ag_grp_pc_lcu_2015', 'man_grp_pc_lcu_2015',
#        'serv_grp_pc_lcu_2015', 'grp_pc_usd_2015', 'ag_grp_pc_usd_2015',
#        'man_grp_pc_usd_2015', 'serv_grp_pc_usd_2015', 'grp_pc_lcu2015_usd',
#        'ag_grp_pc_lcu2015_usd', 'man_grp_pc_lcu2015_usd',
#        'serv_grp_pc_lcu2015_usd', 'cpi_2015', 'deflator_2015', 'fx', 'PPP',
#        'StructChange', 'version', 'T_a', 'P_a'],
#       dtype='object')

# %%
data['time'] = pd.to_datetime(data['year'], unit=None)
data.set_index('region', inplace=True)

# %%
data.tail(5)
# Out:
#               ï»¿country GID_0     GID_1  year       grp_lcu        pop  \
# region
# Äá»ng ThÃ¡p    Vietnam   VNM  VNM.18_1  2014  5.080000e+13  1681300.0
# Äá»ng ThÃ¡p    Vietnam   VNM  VNM.18_1  2015  5.200000e+13  1684300.0
# Äá»ng ThÃ¡p    Vietnam   VNM  VNM.18_1  2016  5.620000e+13  1687300.0
# Äá»ng ThÃ¡p    Vietnam   VNM  VNM.18_1  2017  6.600000e+13  1690300.0
# Äá»ng ThÃ¡p    Vietnam   VNM  VNM.18_1  2018  7.290000e+13  1693300.0
#
#                 grp_pc_lcu  ag_grp_pc_lcu  man_grp_pc_lcu  serv_grp_pc_lcu  \
# region
# Äá»ng ThÃ¡p  30235175.16    11644560.76     6637720.811      11147921.25
# Äá»ng ThÃ¡p  30865641.51    12231787.69     7372795.820      12079795.76
# Äá»ng ThÃ¡p  33286908.08    12610087.12     7782848.338      13439222.43
# Äá»ng ThÃ¡p  39037744.78    13108383.13     8491983.672      15126841.39
# Äá»ng ThÃ¡p  43035610.94    14436130.63     9457922.400      16524242.60
#
# ...

# %%
data.drop(['grp_lcu', 'grp_pc_lcu', 'ag_grp_pc_lcu', 'man_grp_pc_lcu', 'serv_grp_pc_lcu', 'ag_grp_pc_usd', 'man_grp_pc_usd', 'serv_grp_pc_usd',
       'grp_pc_lcu_2015', 'ag_grp_pc_lcu_2015', 'man_grp_pc_lcu_2015',
       'serv_grp_pc_lcu_2015', 'grp_pc_usd_2015', 'ag_grp_pc_usd_2015',
       'man_grp_pc_usd_2015', 'serv_grp_pc_usd_2015', 'grp_pc_lcu2015_usd',
       'ag_grp_pc_lcu2015_usd', 'man_grp_pc_lcu2015_usd',
       'serv_grp_pc_lcu2015_usd', 'deflator_2015', 'fx', 'PPP',
       'StructChange', 'version', 'P_a'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['ï»¿country', 'GID_0', 'GID_1', 'year', 'pop', 'grp_pc_usd', 'cpi_2015',
#        'T_a', 'time'],
#       dtype='object')

# %%
data.drop(['ï»¿country', 'GID_0', 'GID_1'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['year', 'pop', 'grp_pc_usd', 'cpi_2015', 'T_a', 'time'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46797 entries, Berat to Äá»ng ThÃ¡p
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        46797 non-null  int64
#  1   pop         44457 non-null  float64
#  2   grp_pc_usd  46797 non-null  float64
#  3   cpi_2015    46725 non-null  float64
#  4   T_a         39439 non-null  float64
#  5   time        46797 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 2.5+ MB

# %%
print('so far, so good')
# Out:
# so far, so good

# %%
x = data['pop']
y = data['grp_pc_usd']

# %%
plt.scatter(x, y)
plt.xlabel('Regional Population', fontsize=20)
plt.ylabel('Gross Regional Product', fontsize=20)
plt.show()

# %%
train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

# %%
plt.scatter(train_x, train_y)
plt.show()

# %%
plt.scatter(test_x, test_y)
plt.show()

# %%
myModel = np.poly1d(np.polyfit(train_x, train_y, 4))

myLine = np.linspace(0, 300000)

plt.scatter(train_x, train_y)
plt.plot(myLine, myModel(myLine))
plt.show()

# %%
from sklearn.metrics import r2_score
r2 = r2_score(train_y, myModel(train_x))
print(r2)
# Out:
# 0.2845759603741038

# %%
for col in data.columns:
    if data[col].isna().any():
        mode = data[col].mode()[0]
        data[col] = data[col].fillna(mode)

# %%
import numpy
from sklearn.metrics import r2_score

myModel = np.poly1d(np.polyfit(train_x, train_y, 4))

r2 = r2_score(test_y, myModel(test_x))

print(r2)
# Out:
# -6.760917541544964e+19

# %%
print(myModel(300000))
# Out:
# 4203.685992210699
